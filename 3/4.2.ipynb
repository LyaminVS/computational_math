# %%
import numpy as np
import matplotlib.pyplot as plt

H = np.array([8, 10, 15, 20, 30, 40, 60, 80])
B = np.array([13.0, 14.0, 15.4, 16.3, 17.2, 17.8, 18.5, 18.8])
alpha = np.array([0.1, 0.1, 1, 1, 1, 1, 1, 1])
plt.scatter(H, B)
x = np.linspace(9, 80, num=1000)
plt.plot(x, x / (0.051 * x + 0.156))
